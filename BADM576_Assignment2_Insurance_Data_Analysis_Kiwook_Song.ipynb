# %% [markdown]
# <a href="https://colab.research.google.com/github/kyook17/BADM576/blob/main/BADM576_Assignment2_Insurance_Data_Analysis_Kiwook_Song.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the Excel file
df = pd.read_csv("https://raw.githubusercontent.com/kyook17/BADM576/main/csv/insurance_marketing_dataset.csv")
print(df.shape, "\n")
df.head()
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
# Select the columns for analysis
columns_for analysis = [
    'Customer Lifetime Value', # Continuous
    'Coverage',                # Ordinal
    'Months Since Last Claim', # Discrete
    'State',                   # Nominal
    'Response'                 # Nominal
]

# Extract the selected columns for descriptive analysis
selected_columns_data = dataset_customers[columns_for_analysis]

# Perform descriptive analysis for each selected column

# For the continuous column 'Customer Lifetime Value'
customer_lifetime_value_stats = selected_columns_data['Customer Lifetime Value'].describe()

# For the ordinal column 'Coverage'
coverage_counts = selected_columns_data['Coverage'].value_counts()

# For the discrete column 'Months Since Last Claim'
months_since_last_claim_stats = selected_columns_data['Months Since Last Claim'].describe()
months_since_last_claim_freq = selected_columns_data['Months Since Last Claim'].value_counts()

# For the nominal column 'State'
state_counts = selected_columns_data['State'].value_counts()

# For the nominal column 'Response'
response_counts = selected_columns_data['Response'].value_counts()

# Print out the descriptive statistics
print("Customer Lifetime Value Stats:\n", customer_lifetime_value_stats)
print("\nCoverage Counts:\n", coverage_counts)
print("\nMonths Since Last Claim Stats:\n", months_since_last_claim_stats)
print("\nMonths Since Last Claim Frequencies:\n", months_since_last_claim_freq)
print("\nState Counts:\n", state_counts)
print("\nResponse Counts:\n", response_counts)
